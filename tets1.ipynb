# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\LENOVO\Downloads\Prod.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                        Description  \
# 0           0  (150)  Opérateurs Et Opératrices De Câblage Au...
# 1           1                           (1)  CUISINER DE CANTINE
# 2           2  (50)   Opérateur Sur Machine Mécanisée1 De Câb...
# 3           3                     (1)  Vendeuse En Pharmacie (F)
# 4           4                        (5)  Hôte Hôtesse De Caisse
#
#                                                 Lien Contrat           Lieu  \
# 0  http://anapec.org/sigec-app-rv/fr/entreprises/...     CDI  CASA-BEN MSIK
# 1  http://anapec.org/sigec-app-rv/fr/entreprises/...  JERADA            NaN
# 2  http://anapec.org/sigec-app-rv/fr/entreprises/...      CI         MIDELT
# 3  http://anapec.org/sigec-app-rv/fr/entreprises/...      CI      EL JADIDA
# 4  http://anapec.org/sigec-app-rv/fr/entreprises/...      CI  SLE-AL JADIDA
#
#                                            comptence  \
# 0                                                 []
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   30 non-null     int64
#  1   Description  30 non-null     object
#  2   Lien         30 non-null     object
#  3   Contrat      30 non-null     object
#  4   Lieu         28 non-null     object
#  5   comptence    30 non-null     object
#  6   Date         30 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ KB

# %%
df1=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute_complet.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute_complet.csv")
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Titre du poste          30 non-null     object
#  1   Entreprise              0 non-null      float64
#  2   Description             30 non-null     object
#  3   Date de publication     30 non-null     object
#  4   Secteur d'activité      30 non-null     object
#  5   Fonction                30 non-null     object
#  6   Expérience requise      0 non-null      float64
#  7   Niveau d'étude demandé  0 non-null      float64
#  8   Type de contrat         0 non-null      float64
#  9   Télétravail             30 non-null     object
#  10  Postes proposés         0 non-null      float64
#  11  Lien de l'offre         30 non-null     object
# dtypes: float64(5), object(7)
# memory usage: 2.9+ KB

# %%
df1.head()
# Out:
#                                       Titre du poste  Entreprise  \
# 0  Confirmateur des Rendez-vous H/F | Tanger (Maroc)         NaN
# 1  Téléconseillers en prise des RDVS - Tanger | T...         NaN
# 2      Formateur en Relation Client | Tanger (Maroc)         NaN
# 3  Téléconseiller en prise des Rdvs Panneau Photo...         NaN
# 4  Téléconseiller en prise des Rdvs Rénovations d...         NaN
#
#                                          Description  \
# 0  Impérial Com - L'Esprit de Communication Impér...
# 1  Impérial Com - L'Esprit de Communication Impér...
# 2  Impérial Com - L'Esprit de Communication Impér...
# 3  Impérial Com - L'Esprit de Communication Impér...
# 4  Impérial Com - L'Esprit de Communication Impér...
#
#                                  Date de publication  \
# 0  Publication : du 14/01/2025 au 02/03/2025 | Po...
# 1  Publication : du 14/01/2025 au 12/02/2025 | Po...
# 2  Publication : du 14/01/2025 au 21/02/2025 | Po...
# ...

# %%
df2=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute.csv")

# %%
df2.head()
# Out:
#                                                Titre    Entreprise  \
# 0  Confirmateur des Rendez-vous H/F | Tanger (Maroc)  Imperial Com
# 1  Téléconseillers en prise des RDVS - Tanger | T...  Imperial Com
# 2      Formateur en Relation Client | Tanger (Maroc)  Imperial Com
# 3  Téléconseiller en prise des Rdvs Panneau Photo...  Imperial Com
# 4  Téléconseiller en prise des Rdvs Rénovations d...  Imperial Com
#
#                                          Description  \
# 0  Impérial Com - L'Esprit de Communication\n\n\t...
# 1  Impérial Com - L'Esprit de Communication\n\n\t...
# 2  Impérial Com - L'Esprit de Communication\n\n\t...
# 3  Impérial Com - L'Esprit de Communication\n\n\t...
# 4  Impérial Com - L'Esprit de Communication\n\n\t...
#
#                                  Date de publication Secteur d'activité  \
# 0  Publication : du                              ...     Centre d'appel
# 1  Publication : du                              ...     Centre d'appel
# ...

# %%
df4=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute.csv")

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Titre                50 non-null     object
#  1   Entreprise           50 non-null     object
#  2   Description          50 non-null     object
#  3   Date de publication  50 non-null     object
#  4   Secteur d'activité   50 non-null     object
#  5   Fonction             50 non-null     object
#  6   Expérience requise   50 non-null     object
#  7   Niveau d'étude       50 non-null     object
#  8   Type de contrat      50 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
df4["Titre"].unique()
# Out:
# array(['Confirmateur des Rendez-vous H/F | Tanger (Maroc)',
#        'Téléconseillers en prise des RDVS - Tanger | Tanger (Maroc)',
#        'Formateur en Relation Client | Tanger (Maroc)',
#        'Téléconseiller en prise des Rdvs Panneau Photovoltaïque Débutant ou Expérimenté H/F | Tanger (Maroc)',
#        "Téléconseiller en prise des Rdvs Rénovations d'Ampleur Débutant ou Expérimenté H/F (Tanger) | Tanger (Maroc)",
#        'Eca recrute des commerciaux en assurance :( 5000dhs + primes déplafonnées + transport assuré+..) | Casablanca (Maroc)',
#        'Rejoignez notre équipe en tant que téléconseiller en accompagnement crédit !(4500dh +primes+ we off) | Casablanca (Maroc)',
#        'Network Global Products Financial Controller | Rabat (Maroc)',
#        'Team Manager Francophone (H/F) | Rabat (Maroc)',
#        'Responsable Communication | Casablanca/Tanger (Maroc)',
#        'IT Onsite Engineer | Rabat (Maroc)',
# ...

# %%
df4.head()
# Out:
#                                                Titre  \
# 0  Confirmateur des Rendez-vous H/F | Tanger (Maroc)
# 1  Téléconseillers en prise des RDVS - Tanger | T...
# 2      Formateur en Relation Client | Tanger (Maroc)
# 3  Téléconseiller en prise des Rdvs Panneau Photo...
# 4  Téléconseiller en prise des Rdvs Rénovations d...
#
#                                           Entreprise  \
# 0  Impérial Com - L'Esprit de Communication\n\n\t...
# 1  Impérial Com - L'Esprit de Communication\n\n\t...
# 2  Impérial Com - L'Esprit de Communication\n\n\t...
# 3  Impérial Com - L'Esprit de Communication\n\n\t...
# 4  Impérial Com - L'Esprit de Communication\n\n\t...
#
#                                          Description  \
# 0  Impérial Com - L'Esprit de Communication\n\n\t...
# 1  Impérial Com - L'Esprit de Communication\n\n\t...
# 2  Impérial Com - L'Esprit de Communication\n\n\t...
# 3  Impérial Com - L'Esprit de Communication\n\n\t...
# ...

# %%
df4["Description"]
# Out:
# 0     Impérial Com - L'Esprit de Communication\n\n\t...
# 1     Impérial Com - L'Esprit de Communication\n\n\t...
# 2     Impérial Com - L'Esprit de Communication\n\n\t...
# 3     Impérial Com - L'Esprit de Communication\n\n\t...
# 4     Impérial Com - L'Esprit de Communication\n\n\t...
# 5     Acteur incontournable du courtage en Assurance...
# 6     Acteur incontournable du courtage en Assurance...
# 7     AXA Group Operations – Centre opérationnel d’e...
# 8     Sitel Group devient officiellement Foundever™....
# 9     Sitel Group devient officiellement Foundever™....
# 10    Sitel Group devient officiellement Foundever™....
# 11    Sitel Group devient officiellement Foundever™....
# 12    Impérial Com - L'Esprit de Communication\n\n\t...
# 13    Impérial Com - L'Esprit de Communication\n\n\t...
# 14    Locamed est un leader dans le domaine de distr...
# 15    INNOVX est un groupe multi-sectoriel qui conço...
# 16    INNOVX est un groupe multi-sectoriel qui conço...
# ...

# %%
import pandas as pd

# %%
df5=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\job_listings.csv", encoding='ISO-8859-1')

# %%
l=df5["Compétences clés"][0].split("-")
l
# Out:
# ['Communication ',
#  ' Comptabilité ',
#  ' Gestion ',
#  " Gestion d'Équipe ",
#  ' Marketing ',
#  ' Marketing Direct ',
#  ' Vente']

# %%
len(l)
# Out:
# 7

# %%
df5.iloc[8:14,:]
# Out:
#                                               titre            entreprise  \
# 8         Gestionnaire Moyens Généraux - Casablanca                   ENI
# 9      Mécanicien Industriel - Casablanca Et Région                TECTRA
# 10                                Soudeur - Kénitra                TECTRA
# 11     Technicien Construction Métallique  - Zenata                TECTRA
# 12  Chargé(e) de Production Assurance  - Casablanca         GROUPE TECTRA
# 13                    Agent Immobilier - Casablanca  BARNES LS CASABLANCA
#
#              localisation                                   competences_cles  \
# 8   Casablanca-Mohammedia                         Achats - Transport - Vente
# 9   Casablanca-Mohammedia  Industrie - Maintenance - Maintenance Industri...
# 10     Rabat-Salé-Kénitra                 Maintenance - Production - Qualité
# 11  Casablanca-Mohammedia    Construction Métallique - Maintenance - Qualité
# ...

# %%
df6["date_publication"].unique()
# Out:
# array(['15.01.2025'], dtype=object)

# %%
import pandas as pd

df10.iloc[3:11,:]
# Out:
# Empty DataFrame
# Columns: [Date de publication, date_publication, date_limit]
# Index: []

# %%
import pandas as pd
df10=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute.csv")
df10.iloc[3:4,:]
# Out:
#                     titre entreprise  \
# 3  Tech Lead Java/Angular   Devoteam
#
#                                          description   localisation  \
# 3  En tant que Tech Lead Java au sein de Devoteam...  Rabat (Maroc)
#
#                          Date de publication    Nombre de postes  \
# 3  Publication : du 16/01/2025 au 29/01/2025  Postes proposés: 3
#
#   niveau_experience niveau_etudes_requis                    competences_cles  \
# 3     De 5 à 10 ans       Bac +5 et plus  ['Informatique ', ' Electronique']
#
#   contrat_propose teletravail  \
# 3             CDI         Non
#
#                                                 lien
# 3  https://www.rekrute.com/offre-emploi-tech-lead...

# %%
str_test
# Out:
# '16/01/2025'

# %%
# all lignes
df10["date_publication"] = ""
df10["date_limit"] = ""
for i in range(0, len(df10)):
    str_test=df10["Date de publication"][i]
    phase1= str_test.split("du")
    dates=phase1[1]
    phase2=dates.split("au")
    df10["date_publication"][i]= phase2[0].strip().replace("/",".")
    df10["date_limit"][i]=phase2[1].strip().replace("/",".")

# %%
# Exemple de DataFrame
data = {"Date de publication": ["du 16/01/2025 au 29/01/2025", "du 16.01.2025 au 16.03.2025"]}
df10 = pd.DataFrame(data)

# Extraction des dates
df10["date_publication"] = df10["Date de publication"].str.extract(r"du\s*([\d/\.]+)")
df10["date_limit"] = df10["Date de publication"].str.extract(r"au\s*([\d/\.]+)")
df10["date_publication"] = df10["date_publication"].str.replace("/", ".", regex=False)
df10["date_limit"] = df10["date_limit"].str.replace("/", ".", regex=False)

print(df10)

# %%
df10
# Out:
#                                                titre  \
# 0                            Technical Sales Manager
# 1   Administrateur Systèmes & Bases De Données (H/F)
# 2                    Développeur Java/Angular Sénior
# 3                             Tech Lead Java/Angular
# 4           Développeur(e) expérimenté en Java/React
# 5                     Production workshop Supervisor
# 6                              Cloud Security Expert
# 7  Chargé(e) clientèle service technique en récep...
# 8                              conseiller commercial
# 9                                      Commercial VO
#
#                        entreprise  \
# 0                    SGS Maroc SA
# 1                           Sorec
# 2                        Devoteam
# 3                        Devoteam
# 4                        Devoteam
# 5                           COBCO
# 6      AXA Group Operations Maroc
# 7                Manpower Agences
# 8  Meski Invest - Riva Industries
# ...

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   titre                 10 non-null     object
#  1   entreprise            10 non-null     object
#  2   description           10 non-null     object
#  3   localisation          10 non-null     object
#  4   Date de publication   10 non-null     object
#  5   Nombre de postes      10 non-null     object
#  6   niveau_experience     10 non-null     object
#  7   niveau_etudes_requis  10 non-null     object
#  8   competences_cles      10 non-null     object
#  9   contrat_propose       10 non-null     object
#  10  teletravail           10 non-null     object
#  11  lien                  10 non-null     object
# dtypes: object(12)
# memory usage: 1.1+ KB

# %%
df10.columns
# Out:
# Index(['titre', 'entreprise', 'description', 'localisation',
#        'Date de publication', 'Nombre de postes', 'niveau_experience',
#        'niveau_etudes_requis', 'competences_cles', 'contrat_propose',
#        'teletravail', 'lien'],
#       dtype='object')

# %%
phase1= str_test.split("du")
dates=phase1[1]
phase2=dates.split("au")
date_publication = phase2[0].strip().replace("/",".")
date_limit=phase2[1].strip().replace("/",".")

# %%
date_publication , date_limit
# Out:
# ('16.01.2025', '16.03.2025')

# %%
df11=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute.csv")

# %%
df11.head()
# Out:
#                                      titre  \
# 0      Industry Analyst - Business Partner
# 1  Chargé de clientèle en agence BENGUERIR
# 2           Assistant(e) Back Office (H/F)
# 3                  Auditeur Confirmé (H/F)
# 4                    Auditeur Sénior (H/F)
#
#                                    entreprise  \
# 0                             Orange Business
# 1                            Manpower Agences
# 2  Maroc Climate and Security (MCS) - Carrier
# 3                                         PwC
# 4                                         PwC
#
#                                          description        localisation  \
# 0  Au sein du Groupe Orange, Orange Business est ...  Casablanca (Maroc)
# 1  Principales missions: - Accueillir les clients...   Benguerir (Maroc)
# 2  Dans le cadre de son développement, la société...  Casablanca (Maroc)
# 3  Quel sera votre rôle dans les équipes de PWC S...  Casablanca (Maroc)
# ...

# %%
df11["date_publication"].unique()
# Out:
# array(['16/01/2025'], dtype=object)

# %%
df11["date_limite"].unique()
# Out:
# array(['13/03/2025', '03/03/2025', '16/03/2025'], dtype=object)

# %%
df12=pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\offres_rekrute.csv")

# %%
df12.head()
# Out:
#                                                titre          entreprise  \
# 0                   Chargé De Développement RH (H/F)             AKDITAL
# 1         Responsable Planification & Ordonnancement               Duroc
# 2              Testeur Informatique Anglophone (H/F)  AXA Services Maroc
# 3                   HR Business Partner (HRBP) (H/F)                 NaN
# 4  Chargé(e) de clientèle en émission d'appels - ...      Eca Assurances
#
#                                          description  \
# 0  En tant que Chargé (e) développement RH , vous...
# 1  Dans le cadre du développement de nos activité...
# 2  Le Testeur Informatique a pour missions princi...
# 3  Les missions: Accompagnement des managers et s...
# 4  Dans le cadre de la poursuite de notre dévelop...
#
#                localisation  \
# 0        Casablanca (Maroc)
# 1            Agadir (Maroc)
# 2  Salé Technopolis (Maroc)
# 3            Tanger (Maroc)
# 4        Casablanca (Maroc)
#
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\LENOVO\Desktop\project_job\scraping_rekrute_com\offres_rekrute.csv")

# %%
df.iloc[3:8,:]
# Out:
#                                                titre  \
# 3                    Compliance and Privacy Champion
# 4    Consultant Senior Cyber Security/ Privacy (H/F)
# 5  Coordinateur Production et Développement Produ...
# 6      Responsable Crédit Management et Recouvrement
# 7                              Project Manager (H/F)
#
#                             entreprise  \
# 3           Foundever (ex Sitel Group)
# 4                           KPMG Maroc
# 5  Beaumanoir Maroc Sourcing Et Export
# 6                         Super Cérame
# 7                      Pratt & Whitney
#
#                                          description        localisation  \
# 3  Serve as the first point of contact for addres...  Casablanca (Maroc)
# 4  Votre mission, en tant que consultant(e) Senio...  Casablanca (Maroc)
# 5  Rattaché(e) au Merchandiser Manager, votre mis...  Casablanca (Maroc)
# 6  Rejoignez notre équipe dans le secteur du BTP ...  Casablanca (Maroc)
# ...

# %%
df["date_publication"]
# Out:
# 0    Publication : du 16/01/2025 au 16/03/2025
# 1                                          NaN
# 2    Publication : du 16/01/2025 au 16/03/2025
# 3    Publication : du 16/01/2025 au 16/03/2025
# 4    Publication : du 16/01/2025 au 16/03/2025
# 5    Publication : du 16/01/2025 au 16/03/2025
# 6                                          NaN
# 7    Publication : du 16/01/2025 au 09/03/2025
# 8    Publication : du 16/01/2025 au 16/03/2025
# 9    Publication : du 16/01/2025 au 16/03/2025
# Name: date_publication, dtype: object

# %%
with open(r"scraping_rekrute_com\offres_rekrute.csv", "r") as file :
    line1 = file.readline() 
    line2 = file.readline()
    print(line1)
    print(line2)
    file.close()
# Out:
# titre,entreprise,description,localisation,date_publication,date_limite,nombre_postes,niveau_experience,niveau_etudes_requis,competences_cles,contrat_propose,teletravail,lien
#
# ContrÃ´leur Financier Senior,,"RattachÃ©(e) au Directeur Administratif & Financier, vous jouerez un rÃ´le clÃ© dans la gestion des opÃ©rations administratives liÃ©es Ã  la gestion financiÃ¨re et Ã  la performance globale de...",Casablanca (Maroc),16.01.2025,16.03.2025,Postes proposÃ©s: 1,De 5 Ã  10 ans,Bac +5 et plus,"['Gestion ', ' ComptabilitÃ© ', ' Finance']",CDI,Non,https://www.rekrute.com/offre-emploi-controleur-financier-senior-recrutement-confidentiel-casablanca-167764.html

# %%
def sum(a,b):
    return a+b
s=sum(2,3)
s
# Out:
# 5

# %%
import smtplib

try:
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.starttls()
    server.login('abdeladimebenali2003@gmail.com', 'hpkq anvr qcem plnw')
    print("Connexion réussie !")
    server.quit()
except Exception as e:
    print(f"Erreur : {e}")
# Out:
# Erreur : [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
